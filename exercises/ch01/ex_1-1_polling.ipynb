# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
poll_url = '../../data/president_polls_2016.csv'
polls = pd.read_csv(poll_url)

# %%
polls.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson    11/8/2016
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson    11/8/2016
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson    11/8/2016
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson    11/8/2016
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson    11/8/2016
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 0         45.20163      41.72430         4.626221               NaN
# 1         43.34557      41.21439         5.175792               NaN
# 2         42.02638      38.81620         6.844734               NaN
# 3         45.65676      40.92004         6.069454               NaN
# 4         46.84089      42.33184         3.726098               NaN
#
#    multiversions                                                url  poll_id  \
# 0            NaN  https://www.washingtonpost.com/news/the-fix/wp...    48630
# 1            NaN  https://datastudio.google.com/u/0/#/org//repor...    48847
# 2            NaN  http://projects.fivethirtyeight.com/polls/2016...    48922
# 3            NaN  https://d25d2506sfb94s.cloudfront.net/cumulus_...    48687
# 4            NaN  http://www.gravispolls.com/2016/11/final-natio...    48848
#
#    question_id  createddate       timestamp
# 0        76192    11/7/2016  11/8/2016 9:35
# 1        76443    11/7/2016  11/8/2016 9:35
# 2        76636    11/8/2016  11/8/2016 9:35
# 3        76262    11/7/2016  11/8/2016 9:35
# 4        76444    11/7/2016  11/8/2016 9:35
#
# [5 rows x 27 columns]

# %%
polls = polls.sort_values('state')
polls.head(2)
# Out:
#        cycle     branch        type                        matchup  \
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 4610    2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate    enddate                 pollster  \
# 12475    11/8/2016  Alabama  10/21/2016  11/2/2016                    Ipsos
# 4610     11/8/2016  Alabama   11/1/2016  11/7/2016  Google Consumer Surveys
#
#       grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 12475    A-  ...         40.48323      53.28125              NaN
# 4610      B  ...         25.54403      66.17603          3.75508
#
#        adjpoll_mcmullin  multiversions  \
# 12475               NaN            NaN
# 4610                NaN            NaN
#
#                                                      url  poll_id  \
# 12475          http://www.reuters.com/statesofthenation/    48213
# 4610   https://datastudio.google.com/u/0/#/org//repor...    48794
#
#        question_id  createddate       timestamp
# 12475        75514    11/3/2016  11/8/2016 9:14
# 4610         76383    11/7/2016  11/8/2016 9:24
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Use Tab completion and tooltips

# %%
polls.sort_values('state', ascending=False).head()
# Out:
#        cycle     branch        type                        matchup  \
# 5595    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 9368    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 11204   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 1336    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 10098   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 5595     11/8/2016  Wyoming  10/24/2016  10/30/2016             SurveyMonkey
# 9368     11/8/2016  Wyoming  10/25/2016  10/31/2016  Google Consumer Surveys
# 11204    11/8/2016  Wyoming   8/24/2016   8/30/2016  Google Consumer Surveys
# 1336     11/8/2016  Wyoming  10/25/2016  10/31/2016             SurveyMonkey
# 10098    11/8/2016  Wyoming  10/10/2016  10/14/2016  Google Consumer Surveys
#
#       grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 5595     C-  ...         21.66060      62.70650         4.911339
# 9368      B  ...         32.16531      63.84652         2.557269
# 11204     B  ...         29.19806      52.00241         5.173976
# 1336     C-  ...         20.71510      62.43554         7.034882
# 10098     B  ...         22.26467      60.78201         9.642412
#
#        adjpoll_mcmullin  multiversions  \
# 5595                NaN            NaN
# 9368                NaN            NaN
# 11204               NaN            NaN
# 1336                NaN            NaN
# 10098               NaN            NaN
#
#                                                      url  poll_id  \
# 5595   https://www.surveymonkey.com/elections/map?pol...    47844
# 9368   https://datastudio.google.com/u/0/#/org//repor...    47992
# 11204  https://drive.google.com/drive/u/0/folders/0B2...    45540
# 1336   https://www.surveymonkey.com/elections/map?pol...    47933
# 10098  https://datastudio.google.com/u/0/#/org//repor...    47006
#
#        question_id  createddate       timestamp
# 5595         74867   10/31/2016  11/8/2016 9:24
# 9368         75051    11/1/2016  11/8/2016 9:14
# 11204        70925     9/9/2016  11/8/2016 9:14
# 1336         74989    11/1/2016  11/8/2016 9:35
# 10098        73495   10/17/2016  11/8/2016 9:14
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### Keep only the rows with "now-cast" in the type column

# %%
polls = polls.query('type=="now-cast"')
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 4610   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 5997   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 7530   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 4369   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
#
#         state   startdate    enddate                 pollster grade  ...  \
# 4610  Alabama   11/1/2016  11/7/2016  Google Consumer Surveys     B  ...
# 5997  Alabama  10/27/2016  11/2/2016             SurveyMonkey    C-  ...
# 7530  Alabama   8/17/2016  8/23/2016  Google Consumer Surveys     B  ...
# 4369  Alabama   11/1/2016  11/7/2016             SurveyMonkey    C-  ...
# 5504  Alabama   7/19/2016  7/19/2016        Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 4610         25.54403      66.17603         3.755080               NaN
# 5997         33.63222      52.90133         2.269698               NaN
# 7530         25.27439      65.91888         1.217370               NaN
# 4369         34.52791      54.35276         3.682124               NaN
# 5504         34.09074      57.64280              NaN               NaN
#
#       multiversions                                                url  \
# 4610            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 5997            NaN  https://www.surveymonkey.com/elections/map?pol...
# 7530            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 4369            NaN  https://www.surveymonkey.com/elections/map?pol...
# 5504            NaN  http://wkrg.com/2016/07/21/trump-wins-alabama-...
#
#       poll_id  question_id  createddate       timestamp
# 4610    48794        76383    11/7/2016  11/8/2016 9:24
# 5997    48129        75398    11/3/2016  11/8/2016 9:24
# 7530    45542        70927     9/9/2016  11/8/2016 9:24
# 4369    48860        76550    11/8/2016  11/8/2016 9:24
# 5504    44747        68431     8/2/2016  11/8/2016 9:24
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Rename voting columns

# %%
polls = polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
                              'rawpoll_trump':'Trump_pct'})
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 4610   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 5997   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 7530   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 4369   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
#
#         state   startdate    enddate                 pollster grade  ...  \
# 4610  Alabama   11/1/2016  11/7/2016  Google Consumer Surveys     B  ...
# 5997  Alabama  10/27/2016  11/2/2016             SurveyMonkey    C-  ...
# 7530  Alabama   8/17/2016  8/23/2016  Google Consumer Surveys     B  ...
# 4369  Alabama   11/1/2016  11/7/2016             SurveyMonkey    C-  ...
# 5504  Alabama   7/19/2016  7/19/2016        Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 4610         25.54403      66.17603         3.755080               NaN
# 5997         33.63222      52.90133         2.269698               NaN
# 7530         25.27439      65.91888         1.217370               NaN
# 4369         34.52791      54.35276         3.682124               NaN
# 5504         34.09074      57.64280              NaN               NaN
#
#       multiversions                                                url  \
# 4610            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 5997            NaN  https://www.surveymonkey.com/elections/map?pol...
# 7530            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 4369            NaN  https://www.surveymonkey.com/elections/map?pol...
# 5504            NaN  http://wkrg.com/2016/07/21/trump-wins-alabama-...
#
#       poll_id  question_id  createddate       timestamp
# 4610    48794        76383    11/7/2016  11/8/2016 9:24
# 5997    48129        75398    11/3/2016  11/8/2016 9:24
# 7530    45542        70927     9/9/2016  11/8/2016 9:24
# 4369    48860        76550    11/8/2016  11/8/2016 9:24
# 5504    44747        68431     8/2/2016  11/8/2016 9:24
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Convert date columns to datetime objects

# %%
date_cols = ["startdate","enddate"]
polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 4610   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 5997   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 7530   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 4369   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
# 5504   2016  President  now-cast  Clinton vs. Trump vs. Johnson    11/8/2016
#
#         state  startdate    enddate                 pollster grade  ...  \
# 4610  Alabama 2016-11-01 2016-11-07  Google Consumer Surveys     B  ...
# 5997  Alabama 2016-10-27 2016-11-02             SurveyMonkey    C-  ...
# 7530  Alabama 2016-08-17 2016-08-23  Google Consumer Surveys     B  ...
# 4369  Alabama 2016-11-01 2016-11-07             SurveyMonkey    C-  ...
# 5504  Alabama 2016-07-19 2016-07-19        Strategy Research   NaN  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 4610         25.54403      66.17603         3.755080               NaN
# 5997         33.63222      52.90133         2.269698               NaN
# 7530         25.27439      65.91888         1.217370               NaN
# 4369         34.52791      54.35276         3.682124               NaN
# 5504         34.09074      57.64280              NaN               NaN
#
#       multiversions                                                url  \
# 4610            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 5997            NaN  https://www.surveymonkey.com/elections/map?pol...
# 7530            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 4369            NaN  https://www.surveymonkey.com/elections/map?pol...
# 5504            NaN  http://wkrg.com/2016/07/21/trump-wins-alabama-...
#
#       poll_id  question_id  createddate       timestamp
# 4610    48794        76383    11/7/2016  11/8/2016 9:24
# 5997    48129        75398    11/3/2016  11/8/2016 9:24
# 7530    45542        70927     9/9/2016  11/8/2016 9:24
# 4369    48860        76550    11/8/2016  11/8/2016 9:24
# 5504    44747        68431     8/2/2016  11/8/2016 9:24
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Try two plots

# %%
polls.plot.line(x='enddate', y=['Clinton_pct','Trump_pct'])
# Out:
# <Axes: xlabel='enddate'>

# %%
# %%time
polls.query('state == "U.S."') \
    .plot(x='enddate', y=['Clinton_pct', 'Trump_pct'])
# Out:
# CPU times: user 28.1 ms, sys: 12.7 ms, total: 40.7 ms
# Wall time: 68.1 ms
# <Axes: xlabel='enddate'>

# %%
# %whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# date_cols   list         n=2
# pd          module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# poll_url    str          ../../data/president_polls_2016.csv
# polls       DataFrame          cycle     branch   <...>n[4208 rows x 27 columns]

# %%
type(polls)
# Out:
# pandas.core.frame.DataFrame
